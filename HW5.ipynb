# %% [markdown]
# # HW5 clustering ( 50 pts )

# %% [markdown]
# The goal of this homework is implementing clustering algorithms on 4 given datasets, and then visualize the results.
#
# **Test algorithms:**
# 1. You should include k-means, spectral clustering, DBSCAN, and Hierarchical clustering in your solution.
# 2. For Hierarchical clustering, you should use at least 3 different similarity criteria.
# 3. You should also try another clustering algorithm which is not covered in the lecture.
#
# **Dataset:** (for the first three datasets, you should not use the last column when you run clustering algorithms)
# 1. Aggregation: url="https://raw.githubusercontent.com/liaochunyang/PIC16/main/PIC16B/05_Clustering/Aggregation.txt"
# 2. jain: url="https://raw.githubusercontent.com/liaochunyang/PIC16/main/PIC16B/05_Clustering/jain.txt"
# 3. R15: url="https://raw.githubusercontent.com/liaochunyang/PIC16/main/PIC16B/05_Clustering/R15.txt"
# 4. circle: url="https://raw.githubusercontent.com/liaochunyang/PIC16/main/PIC16B/05_Clustering/circle.csv"
#
# **Visualization::**
# Visualize your results like given sample plot.
# ![clustering.png](attachment:clustering.png)
# **Computation times are included in my sample plots. However, you do NOT need to include them.**

# %% [markdown]
# ## Grading policy:
#
# - Your codes are correct. **(5 pts)** You will receive full credits if there is no error message.
#
# - Implement Hierarchical clustering using at least 3 different similarity criteria. **(5 pts)**
#
# - Visualization. Your visualization should be the same as my sample plot, which means that you should use subplots. Each row represents a dataset, and each column is the clustering algorithm. Moreover, you should include informative labels, titles, and etc. **(5 pts)**
#
# - Visualization. Since you know the correct number of clusters (correct visualization), you should try your best to recover the results. This means that you need to try different hyperparameters (e.g. number of clusters, kernels in spectral clustering, and etc.) **(10 pts)**
#
# - Hyperparameter selection. For each algorithm, please state the choice of your hyperparameters clearly. **(10 pts)**
#
# - Explanation on the algorithm which is not covered in the lecture. Remember that you should also try another clustering algorithm which is not covered in the lecture. You should write a short paragraph to explain the algorithm. For example, you should explain the motivation of the algorithm, or how is the algorithm trained, or how to use it for clustering, and etc. Your explanation should NOT be very long and technical. **(10 pts)**
#
# - You should include comments for your codes. **(5 pts)**
#
# **Remark:** Writing functions or classes to simplify your codes is highly recommended, but it is not mandatory.
